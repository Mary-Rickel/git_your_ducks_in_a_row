# %%
### Doing all the imports
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
### Just to be safe!!!
from scipy import *

# %%
img1 = mpimg.imread('image1.png')
image2 = mpimg.imread('image2.png')
im3 = mpimg.imread('image3.png')
img4 = mpimg.imread('image4.png')
### This is all self-explanatory
fig,ax= plt.subplots(1,4)
ax[0].imshow(img1)
ax[1].imshow(image2)
ax[2].imshow(im3)
ax[3].imshow(img4)
plt.axis('off') 
plt.show()

# %%
im1 = img1[::-1]
plt.imshow(im1)
plt.show()

# %%
print(img1.shape,img2.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(img1.shape,img2.shape)
#
# NameError: name 'img2' is not defined

# %%
print(im1.shape, image2.shape)
# Out:
# (386, 300, 4) (486, 281, 4)

# %%
### It's very clear why we're doing this
plt.imshow(im1)
plt.imshow(image2,alpha=0.1)
plt.show()
